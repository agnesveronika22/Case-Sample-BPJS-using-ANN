# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Data**

# %% [markdown]
# ### fkrtl

# %%
data_fkrtl = pd.read_stata('/content/drive/MyDrive/DAMI/TB20152021_fkrtl.dta')
data_fkrtl.head()
# Out:
#      PSTV01    PSTV02    PSTV15 FKP02             FKL02      FKL03      FKL04  \
# 0  96934726  96934726  0.899331        1000801150000582 2015-01-21 2015-01-21
# 1  11315168  11315168  0.938273        1000801150001076 2015-01-13 2015-01-13
# 2  48014275  20325942  0.998232        1000801160000002 2016-01-02 2016-01-06
# 3  78552717   3459550  1.205653        1000801160000219 2016-01-08 2016-01-08
# 4  48014275  20325942  0.998232        1000801160000321 2016-01-11 2016-01-11
#
#    FKL05     FKL06                FKL07  ... FKL39 FKL40 FKL41 FKL42 FKL43  \
# 0  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         NaN               NaN
# 1  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         NaN               NaN
# 2  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
# 3  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
# 4  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
#
#   FKL44 FKL45 FKL46    FKL47    FKL48
# 0               NaN   166300   166300
# 1               NaN   255200   255200
# 2               0.0  1515300  1515300
# 3               0.0   128600   128600
# 4               0.0   166300   166300
#
# [5 rows x 55 columns]

# %%
data_fkrtl.shape
# Out:
# (1583242, 55)

# %%
data_fkrtl.tail()
# Out:
#            PSTV01    PSTV02    PSTV15            FKP02            FKL02  \
# 1583237   5759906  80881339  1.479716  99521219P000543  99591219V000217
# 1583238  34060166  34060166  1.142161  99531219Y000590  99591219V000223
# 1583239  53933488  53933488  1.161441                   99591219V000267
# 1583240  27230440  27230440  1.446868                   99591220V000092
# 1583241  23942287  62394937  1.484943  99531220Y000405  99591220V000190
#
#              FKL03      FKL04        FKL05             FKL06  \
# 1583237 2019-12-18 2019-12-18  DKI JAKARTA  KEPULAUAN SERIBU
# 1583238 2019-12-18 2019-12-18  DKI JAKARTA  KEPULAUAN SERIBU
# 1583239 2019-12-22 2019-12-22  DKI JAKARTA  KEPULAUAN SERIBU
# 1583240 2020-12-11 2020-12-11  DKI JAKARTA  KEPULAUAN SERIBU
# 1583241 2020-12-28 2020-12-28  DKI JAKARTA  KEPULAUAN SERIBU
#
#                        FKL07  ... FKL39 FKL40 FKL41 FKL42 FKL43 FKL44 FKL45  \
# 1583237  Pemerintah provinsi  ...         0.0               0.0
# 1583238  Pemerintah provinsi  ...         0.0               0.0
# 1583239  Pemerintah provinsi  ...         0.0               0.0
# 1583240  Pemerintah provinsi  ...         0.0               0.0
# 1583241  Pemerintah provinsi  ...         0.0               0.0
#
#         FKL46   FKL47   FKL48
# 1583237   0.0  176200  176200
# 1583238   0.0  176200  176200
# 1583239   0.0  176200  176200
# 1583240   0.0  229900  229900
# 1583241   0.0  173400  173400
#
# [5 rows x 55 columns]

# %%
data_fkrtl.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKL02', 'FKL03', 'FKL04',
#        'FKL05', 'FKL06', 'FKL07', 'FKL08', 'FKL09', 'FKL10', 'FKL11', 'FKL12',
#        'FKL13', 'FKL14', 'FKL15', 'FKL15A', 'FKL16', 'FKL16A', 'FKL17',
#        'FKL17A', 'FKL18', 'FKL18A', 'FKL19', 'FKL19A', 'FKL20', 'FKL21',
#        'FKL22', 'FKL23', 'FKL25', 'FKL26', 'FKL27', 'FKL28', 'FKL29', 'FKL30',
#        'FKL31', 'FKL32', 'FKL33', 'FKL34', 'FKL35', 'FKL36', 'FKL37', 'FKL38',
#        'FKL39', 'FKL40', 'FKL41', 'FKL42', 'FKL43', 'FKL44', 'FKL45', 'FKL46',
#        'FKL47', 'FKL48'],
#       dtype='object')

# %%
data_fkrtl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1583242 entries, 0 to 1583241
# Data columns (total 55 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   PSTV01  1583242 non-null  int32
#  1   PSTV02  1583242 non-null  int32
#  2   PSTV15  1583242 non-null  float32
#  3   FKP02   1583242 non-null  object
#  4   FKL02   1583242 non-null  object
#  5   FKL03   1583242 non-null  datetime64[ns]
#  6   FKL04   1583242 non-null  datetime64[ns]
#  7   FKL05   1583242 non-null  category
#  8   FKL06   1583242 non-null  category
#  9   FKL07   1583242 non-null  category
#  10  FKL08   1583242 non-null  category
#  11  FKL09   1583242 non-null  category
#  12  FKL10   1583242 non-null  category
#  13  FKL11   1583242 non-null  category
#  14  FKL12   1583242 non-null  category
#  15  FKL13   1583242 non-null  category
#  16  FKL14   1583242 non-null  category
#  17  FKL15   1583242 non-null  category
#  18  FKL15A  1583242 non-null  object
#  19  FKL16   1583242 non-null  object
#  20  FKL16A  1583242 non-null  object
#  21  FKL17   1583242 non-null  category
#  22  FKL17A  1583242 non-null  object
#  23  FKL18   1583242 non-null  object
#  24  FKL18A  1583242 non-null  object
#  25  FKL19   1583242 non-null  object
#  26  FKL19A  1583242 non-null  object
#  27  FKL20   1583242 non-null  category
#  28  FKL21   1583242 non-null  category
#  29  FKL22   1583242 non-null  int8
#  30  FKL23   1583242 non-null  category
#  31  FKL25   1583241 non-null  category
#  32  FKL26   1583241 non-null  category
#  33  FKL27   1583242 non-null  category
#  34  FKL28   1583242 non-null  category
#  35  FKL29   1583242 non-null  category
#  36  FKL30   1583242 non-null  object
#  37  FKL31   1583242 non-null  category
#  38  FKL32   1583242 non-null  int32
#  39  FKL33   1583242 non-null  object
#  40  FKL34   1522041 non-null  float64
#  41  FKL35   1583242 non-null  object
#  42  FKL36   1583242 non-null  object
#  43  FKL37   1522041 non-null  float64
#  44  FKL38   1583242 non-null  object
#  45  FKL39   1583242 non-null  object
#  46  FKL40   1522041 non-null  float64
#  47  FKL41   1583242 non-null  object
#  48  FKL42   1583242 non-null  object
#  49  FKL43   1522041 non-null  float64
#  50  FKL44   1583242 non-null  object
#  51  FKL45   1583242 non-null  object
#  52  FKL46   1522041 non-null  float64
#  53  FKL47   1583242 non-null  int32
#  54  FKL48   1583242 non-null  int32
# dtypes: category(21), datetime64[ns](2), float32(1), float64(5), int32(5), int8(1), object(20)
# memory usage: 413.9+ MB

# %%
data_fkrtl.dtypes
# Out:
# PSTV01             int32
# PSTV02             int32
# PSTV15           float32
# FKP02             object
# FKL02             object
# FKL03     datetime64[ns]
# FKL04     datetime64[ns]
# FKL05           category
# FKL06           category
# FKL07           category
# FKL08           category
# FKL09           category
# FKL10           category
# FKL11           category
# FKL12           category
# FKL13           category
# FKL14           category
# FKL15           category
# FKL15A            object
# FKL16             object
# FKL16A            object
# FKL17           category
# FKL17A            object
# FKL18             object
# FKL18A            object
# FKL19             object
# FKL19A            object
# FKL20           category
# FKL21           category
# FKL22               int8
# FKL23           category
# FKL25           category
# FKL26           category
# FKL27           category
# FKL28           category
# FKL29           category
# FKL30             object
# FKL31           category
# FKL32              int32
# FKL33             object
# FKL34            float64
# FKL35             object
# FKL36             object
# FKL37            float64
# FKL38             object
# FKL39             object
# FKL40            float64
# FKL41             object
# FKL42             object
# FKL43            float64
# FKL44             object
# FKL45             object
# FKL46            float64
# FKL47              int32
# FKL48              int32
# dtype: object

# %%
data_fkrtl.describe()
# Out:
#              PSTV01        PSTV02        PSTV15         FKL22         FKL32  \
# count  1.583242e+06  1.583242e+06  1.583242e+06  1.583242e+06  1.583242e+06
# mean   1.248185e+08  1.425551e+08  1.020879e+01  3.458324e+01  7.390369e+05
# std    1.383672e+08  1.476768e+08  2.244498e+01  1.318115e+01  2.664309e+06
# min    1.394000e+03  3.687000e+03  1.568037e-01  1.000000e+00  6.670000e+04
# 25%    3.280830e+07  3.529952e+07  1.258935e+00  1.800000e+01  1.833000e+05
# 50%    6.564083e+07  7.107216e+07  3.369289e+00  4.400000e+01  1.904000e+05
# 75%    9.880540e+07  2.993567e+08  9.254922e+00  4.400000e+01  2.683000e+05
# max    4.553809e+08  4.553826e+08  3.659235e+02  8.400000e+01  3.969334e+08
#
#               FKL34         FKL37         FKL40         FKL43         FKL46  \
# count  1.522041e+06  1.522041e+06  1.522041e+06  1.522041e+06  1.522041e+06
# mean   1.656251e+02  7.580593e+03  2.144971e+03  2.275263e+03  1.093044e+03
# std    4.140777e+04  2.399153e+05  2.416425e+05  6.449953e+04  7.529128e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.543009e+07  4.887170e+07  1.033785e+08  3.332900e+06  1.131860e+07
#
#               FKL47         FKL48
# count  1.583242e+06  1.583242e+06
# mean   7.525403e+05  7.522452e+05
# std    2.759764e+06  2.759039e+06
# min    6.670000e+04  0.000000e+00
# 25%    1.833000e+05  1.833000e+05
# 50%    1.904000e+05  1.904000e+05
# 75%    2.683000e+05  2.683000e+05
# max    3.969334e+08  3.969334e+08

# %%
data_fkrtl.isnull().sum()
# Out:
# PSTV01        0
# PSTV02        0
# PSTV15        0
# FKP02         0
# FKL02         0
# FKL03         0
# FKL04         0
# FKL05         0
# FKL06         0
# FKL07         0
# FKL08         0
# FKL09         0
# FKL10         0
# FKL11         0
# FKL12         0
# FKL13         0
# FKL14         0
# FKL15         0
# FKL15A        0
# FKL16         0
# FKL16A        0
# FKL17         0
# FKL17A        0
# FKL18         0
# FKL18A        0
# FKL19         0
# FKL19A        0
# FKL20         0
# FKL21         0
# FKL22         0
# FKL23         0
# FKL25         1
# FKL26         1
# FKL27         0
# FKL28         0
# FKL29         0
# FKL30         0
# FKL31         0
# FKL32         0
# FKL33         0
# FKL34     61201
# FKL35         0
# FKL36         0
# FKL37     61201
# FKL38         0
# FKL39         0
# FKL40     61201
# FKL41         0
# FKL42         0
# FKL43     61201
# FKL44         0
# FKL45         0
# FKL46     61201
# FKL47         0
# FKL48         0
# dtype: int64

# %%
duplicate_fkrtl = data_fkrtl.duplicated()
print(duplicate_fkrtl.sum)
data_fkrtl[duplicate_fkrtl]
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1583237    False
# 1583238    False
# 1583239    False
# 1583240    False
# 1583241    False
# Length: 1583242, dtype: bool>
# Empty DataFrame
# Columns: [PSTV01, PSTV02, PSTV15, FKP02, FKL02, FKL03, FKL04, FKL05, FKL06, FKL07, FKL08, FKL09, FKL10, FKL11, FKL12, FKL13, FKL14, FKL15, FKL15A, FKL16, FKL16A, FKL17, FKL17A, FKL18, FKL18A, FKL19, FKL19A, FKL20, FKL21, FKL22, FKL23, FKL25, FKL26, FKL27, FKL28, FKL29, FKL30, FKL31, FKL32, FKL33, FKL34, FKL35, FKL36, FKL37, FKL38, FKL39, FKL40, FKL41, FKL42, FKL43, FKL44, FKL45, FKL46, FKL47, FKL48]
# Index: []
#
# [0 rows x 55 columns]

# %% [markdown]
# ### fkrtlxsekunder

# %%
data_fkrtlxsekunder = pd.read_stata('/content/drive/MyDrive/DAMI/TB20152021_fkrtldxsekunder.dta')
data_fkrtlxsekunder.head()
# Out:
#               FKL02  FKL24 FKL24A  \
# 0  2603412140001163   H814    H81
# 1  1337801150000108   M199    M19
# 2  1571901150000730  M4909    M49
# 3  3039201150000052   E790    E79
# 4  3376701150000072   N390    N39
#
#                                               FKL24B
# 0               H81 Disorders of vestibular function
# 1                                M19 Other arthrosis
# 2  M49 Spondylopathies in diseases classified els...
# 3  E79 Disorders of purine and pyrimidine metabolism
# 4              N39 Other disorders of urinary system

# %%
data_fkrtlxsekunder.shape
# Out:
# (1562211, 4)

# %%
data_fkrtlxsekunder.tail()
# Out:
#                     FKL02 FKL24 FKL24A                                FKL24B
# 1562206  263771221V005994  I119    I11        I11 Hypertensive heart disease
# 1562207  265941221V001434  N185    N18            N18 Chronic kidney disease
# 1562208  304721221V007754  M179    M17  M17 Gonarthrosis [arthrosis of knee]
# 1562209   54761221V005120  H268    H26                    H26 Other cataract
# 1562210  398031221V006192  J459    J45                            J45 Asthma

# %%
data_fkrtlxsekunder.columns
# Out:
# Index(['FKL02', 'FKL24', 'FKL24A', 'FKL24B'], dtype='object')

# %%
data_fkrtlxsekunder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1562211 entries, 0 to 1562210
# Data columns (total 4 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   FKL02   1562211 non-null  object
#  1   FKL24   1562211 non-null  object
#  2   FKL24A  1562211 non-null  object
#  3   FKL24B  1562211 non-null  object
# dtypes: object(4)
# memory usage: 59.6+ MB

# %%
data_fkrtlxsekunder.dtypes
# Out:
# FKL02     object
# FKL24     object
# FKL24A    object
# FKL24B    object
# dtype: object

# %%
data_fkrtlxsekunder.describe()
# Out:
#                    FKL02    FKL24   FKL24A  \
# count            1562211  1562211  1562211
# unique           1160115     7807     1676
# top     452460620V009697     A162      A16
# freq                  16   103500   148402
#
#                                                    FKL24B
# count                                             1562211
# unique                                               1672
# top     A16 Respiratory tuberculosis, not confirmed ba...
# freq                                               148402

# %%
data_fkrtlxsekunder.isnull().sum()
# Out:
# FKL02     0
# FKL24     0
# FKL24A    0
# FKL24B    0
# dtype: int64

# %%
duplicate_fkrtlxsekunder = data_fkrtlxsekunder.duplicated()
print(duplicate_fkrtlxsekunder.sum)
data_fkrtlxsekunder[duplicate_fkrtlxsekunder]
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1562206    False
# 1562207    False
# 1562208    False
# 1562209    False
# 1562210    False
# Length: 1562211, dtype: bool>
# Empty DataFrame
# Columns: [FKL02, FKL24, FKL24A, FKL24B]
# Index: []

# %% [markdown]
# ### fkrtlnonkapasitas

# %%
data_fkrtlnonkapasitas = pd.read_stata('/content/drive/MyDrive/DAMI/TB20152021_fktpnonkapitasi.dta')
data_fkrtlnonkapasitas.head()
# Out:
#       PSTV01     PSTV02     PSTV15             PNK02      PNK03      PNK04  \
# 0   93858078   93216423   7.659537  183920215Y000376 2015-02-26 2015-02-26
# 1   93747649  346217457   1.800196   19500915Y000074 2015-09-21 2015-09-23
# 2  359887820   72989971   0.959155  250630919P000299 2019-09-26 2019-09-29
# 3   84126594   84126594   1.110887  326360919P001086 2019-09-09 2019-09-12
# 4   87558937   62126532  32.451832  252721019P001142 2019-10-14 2019-10-17
#
#        PNK05               PNK06     PNK07                      PNK08  ...  \
# 0 2015-02-27    SULAWESI SELATAN     BARRU  PEMERINTAH KABUPATEN/KOTA  ...
# 1 2015-09-23  KALIMANTAN SELATAN     TAPIN  PEMERINTAH KABUPATEN/KOTA  ...
# 2 2019-09-29               PAPUA  JAYAPURA                     TNI AD  ...
# 3 2019-09-12         JAWA TENGAH   REMBANG  PEMERINTAH KABUPATEN/KOTA  ...
# 4 2019-10-17         JAWA TENGAH   KEBUMEN  PEMERINTAH KABUPATEN/KOTA  ...
#
#                PNK10 PNK11     PNK12                               PNK13  \
# 0         RAWAT INAP  RITP  PBI APBN                                 NaN
# 1         RAWAT INAP  RITP  PBI APBN                                 NaN
# 2  KLINIK RAWAT INAP  RITP       PPU  A01 Typhoid and paratyphoid fevers
# 3         RAWAT INAP  RITP  PBI APBN  A01 Typhoid and paratyphoid fevers
# 4         RAWAT INAP  RITP  PBI APBN  A01 Typhoid and paratyphoid fevers
#
#   PNK13A PNK14                           PNK15  \
# 0         9999                            9999
# 1         9999                            9999
# 2    A01  A010                   Typhoid fever
# 3    A01   A01  Typhoid and paratyphoid fevers
# 4    A01   A01  Typhoid and paratyphoid fevers
#
#                               PNK16   PNK17   PNK18
# 0   Evakuasi medis / Ambulans Darat  120000  120000
# 1  Rawat Inap di R. Perawatan Biasa  240000  240000
# 2  Rawat Inap di R. Perawatan Biasa  600000  600000
# 3  Rawat Inap di R. Perawatan Biasa  480000  480000
# 4  Rawat Inap di R. Perawatan Biasa  600000  600000
#
# [5 rows x 21 columns]

# %%
data_fkrtlnonkapasitas.shape
# Out:
# (36493, 21)

# %%
data_fkrtlnonkapasitas.tail()
# Out:
#           PSTV01     PSTV02     PSTV15             PNK02      PNK03  \
# 36488  107435122  107435122  17.946516  108680818Y000770 2018-08-06
# 36489  447273237  435380768   2.330930  122070319Y000676 2019-03-09
# 36490   80686271  426470275   1.154869  296600118Y000277 2018-01-20
# 36491   93887676   93887676   3.204735  296600517Y000031 2017-05-03
# 36492   93887676   93887676   3.204735  296600816Y000004 2016-08-01
#
#            PNK04      PNK05             PNK06       PNK07  \
# 36488 2018-08-06 2018-08-06  SULAWESI SELATAN        WAJO
# 36489 2019-03-09 2019-03-09        JAWA TIMUR       TUBAN
# 36490 2018-01-20 2018-01-20       PAPUA BARAT  RAJA AMPAT
# 36491 2017-05-03 2017-05-03       PAPUA BARAT  RAJA AMPAT
# 36492 2016-08-01 2016-08-01       PAPUA BARAT  RAJA AMPAT
#
#                            PNK08  ...           PNK10 PNK11     PNK12  \
# 36488  PEMERINTAH KABUPATEN/KOTA  ...      RAWAT INAP  RJTP  PBI APBN
# 36489  PEMERINTAH KABUPATEN/KOTA  ...      RAWAT INAP  RJTP      PBPU
# 36490  PEMERINTAH KABUPATEN/KOTA  ...  NON RAWAT INAP  RJTP  PBI APBD
# 36491  PEMERINTAH KABUPATEN/KOTA  ...  NON RAWAT INAP  RJTP  PBI APBD
# 36492  PEMERINTAH KABUPATEN/KOTA  ...  NON RAWAT INAP  RJTP  PBI APBD
#
#                                PNK13 PNK13A PNK14  \
# 36488  Z97 Presence of other devices    Z97  Z975
# 36489  Z97 Presence of other devices    Z97  Z975
# 36490  Z97 Presence of other devices    Z97  Z975
# 36491  Z97 Presence of other devices    Z97  Z975
# 36492  Z97 Presence of other devices    Z97  Z975
#
#                                                  PNK15  \
# 36488  Presence of (intrauterine) contraceptive device
# 36489  Presence of (intrauterine) contraceptive device
# 36490  Presence of (intrauterine) contraceptive device
# 36491  Presence of (intrauterine) contraceptive device
# 36492  Presence of (intrauterine) contraceptive device
#
#                                          PNK16   PNK17   PNK18
# 36488  Pelayanan KB : Pemasangan IUD / Implant  100000  100000
# 36489  Pelayanan KB : Pemasangan IUD / Implant  100000  100000
# 36490                    Pelayanan KB : Suntik   15000   15000
# 36491                    Pelayanan KB : Suntik   15000   15000
# 36492                    Pelayanan KB : Suntik   15000   15000
#
# [5 rows x 21 columns]

# %%
data_fkrtlnonkapasitas.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'PNK02', 'PNK03', 'PNK04', 'PNK05',
#        'PNK06', 'PNK07', 'PNK08', 'PNK09', 'PNK10', 'PNK11', 'PNK12', 'PNK13',
#        'PNK13A', 'PNK14', 'PNK15', 'PNK16', 'PNK17', 'PNK18'],
#       dtype='object')

# %%
data_fkrtlnonkapasitas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36493 entries, 0 to 36492
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PSTV01  36493 non-null  int32
#  1   PSTV02  36493 non-null  int32
#  2   PSTV15  36493 non-null  float32
#  3   PNK02   36493 non-null  object
#  4   PNK03   36493 non-null  datetime64[ns]
#  5   PNK04   36493 non-null  datetime64[ns]
#  6   PNK05   36493 non-null  datetime64[ns]
#  7   PNK06   36493 non-null  category
#  8   PNK07   36493 non-null  category
#  9   PNK08   36493 non-null  category
#  10  PNK09   36493 non-null  category
#  11  PNK10   36493 non-null  category
#  12  PNK11   36493 non-null  category
#  13  PNK12   36493 non-null  category
#  14  PNK13   36491 non-null  category
#  15  PNK13A  36493 non-null  object
#  16  PNK14   36493 non-null  object
#  17  PNK15   36493 non-null  object
#  18  PNK16   36493 non-null  category
#  19  PNK17   36493 non-null  int32
#  20  PNK18   36493 non-null  int32
# dtypes: category(9), datetime64[ns](3), float32(1), int32(4), object(4)
# memory usage: 3.3+ MB

# %%
data_fkrtlnonkapasitas.dtypes
# Out:
# PSTV01             int32
# PSTV02             int32
# PSTV15           float32
# PNK02             object
# PNK03     datetime64[ns]
# PNK04     datetime64[ns]
# PNK05     datetime64[ns]
# PNK06           category
# PNK07           category
# PNK08           category
# PNK09           category
# PNK10           category
# PNK11           category
# PNK12           category
# PNK13           category
# PNK13A            object
# PNK14             object
# PNK15             object
# PNK16           category
# PNK17              int32
# PNK18              int32
# dtype: object

# %%
data_fkrtlnonkapasitas.describe()
# Out:
#              PSTV01        PSTV02        PSTV15         PNK17         PNK18
# count  3.649300e+04  3.649300e+04  36493.000000  3.649300e+04  3.649300e+04
# mean   1.033491e+08  1.259502e+08     10.189317  1.353351e+05  1.353351e+05
# std    1.224665e+08  1.390374e+08     21.183065  2.245414e+05  2.245414e+05
# min    6.563800e+04  6.893000e+04      0.376170  0.000000e+00  0.000000e+00
# 25%    3.120950e+07  3.389082e+07      1.516612  2.500000e+04  2.500000e+04
# 50%    6.113467e+07  6.568918e+07      4.347620  4.500000e+04  4.500000e+04
# 75%    8.974764e+07  9.855116e+07     10.225730  1.200000e+05  1.200000e+05
# max    4.553364e+08  4.553826e+08    324.528839  5.625000e+06  5.625000e+06

# %%
data_fkrtlnonkapasitas.isnull().sum()
# Out:
# PSTV01    0
# PSTV02    0
# PSTV15    0
# PNK02     0
# PNK03     0
# PNK04     0
# PNK05     0
# PNK06     0
# PNK07     0
# PNK08     0
# PNK09     0
# PNK10     0
# PNK11     0
# PNK12     0
# PNK13     2
# PNK13A    0
# PNK14     0
# PNK15     0
# PNK16     0
# PNK17     0
# PNK18     0
# dtype: int64

# %%
duplicate_fkrtlnonkapasitas = data_fkrtlnonkapasitas.duplicated()
duplicate_fkrtlnonkapasitas.sum()
# Out:
# 487

# %% [markdown]
# ### kepersertaan_2019

# %%
data_kepersertaan2019 = pd.read_stata('/content/drive/MyDrive/DAMI/TB2019_kepesertaan.dta')
data_kepersertaan2019.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06  \
# 0   21611150   21611150 1957-09-12  PESERTA  PEREMPUAN        KAWIN
# 1   94343049   96772919 1961-12-03    SUAMI  LAKI-LAKI        KAWIN
# 2   83393824  298548714 2002-10-05     ANAK  LAKI-LAKI  BELUM KAWIN
# 3  328537885  328537885 1989-07-13  PESERTA  PEREMPUAN  BELUM KAWIN
# 4   67805935   67805935 1972-11-13  PESERTA  LAKI-LAKI        KAWIN
#
#       PSTV07    PSTV08 PSTV09         PSTV10                     PSTV11  \
# 0    KELAS I       PPU   ACEH     ACEH BESAR  PEMERINTAH KABUPATEN/KOTA
# 1    KELAS I       PPU   ACEH  ACEH TENGGARA  PEMERINTAH KABUPATEN/KOTA
# 2    KELAS I       PPU   ACEH  ACEH TENGGARA  PEMERINTAH KABUPATEN/KOTA
# 3  KELAS III  PBI APBD   ACEH   ACEH TAMIANG  PEMERINTAH KABUPATEN/KOTA
# 4    KELAS I       PPU   ACEH   ACEH TAMIANG  PEMERINTAH KABUPATEN/KOTA
#
#       PSTV12 PSTV13         PSTV14    PSTV15  PSTV16 PSTV17  PSTV18
# 0  PUSKESMAS   ACEH     ACEH BESAR  1.157796    2019  AKTIF     NaN
# 1  PUSKESMAS   ACEH  ACEH TENGGARA  1.556821    2019  AKTIF     NaN
# 2  PUSKESMAS   ACEH  ACEH TENGGARA  1.159913    2019  AKTIF     NaN
# 3  PUSKESMAS   ACEH   ACEH TAMIANG  9.436164    2019  AKTIF     NaN
# 4  PUSKESMAS   ACEH   ACEH TAMIANG  0.899331    2019  AKTIF     NaN

# %%
data_kepersertaan2019.shape
# Out:
# (94966, 18)

# %%
data_kepersertaan2019.tail()
# Out:
#           PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06  \
# 94961  446945417  446945417 1984-12-31  PESERTA  LAKI-LAKI        KAWIN
# 94962  339605943  286316180 1989-03-17    ISTRI  PEREMPUAN        KAWIN
# 94963  292512825  301371045 1979-05-31    ISTRI  PEREMPUAN        KAWIN
# 94964  412069355  412069355 1970-02-17  PESERTA  LAKI-LAKI        KAWIN
# 94965  354440860  354440860 2000-09-23  PESERTA  PEREMPUAN  BELUM KAWIN
#
#           PSTV07 PSTV08               PSTV09           PSTV10  \
# 94961  KELAS III   PBPU  NUSA TENGGARA BARAT     LOMBOK BARAT
# 94962  KELAS III   PBPU           JAWA BARAT         SUKABUMI
# 94963  KELAS III   PBPU     SUMATERA SELATAN     EMPAT LAWANG
# 94964  KELAS III   PBPU       SUMATERA UTARA  TAPANULI TENGAH
# 94965   KELAS II   PBPU          JAWA TENGAH         PEMALANG
#
#                           PSTV11       PSTV12               PSTV13  \
# 94961  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS  NUSA TENGGARA BARAT
# 94962  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS           JAWA BARAT
# 94963                     SWASTA  DOKTER UMUM     SUMATERA SELATAN
# 94964                     SWASTA  DOKTER UMUM       SUMATERA UTARA
# 94965  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          JAWA TENGAH
#
#                 PSTV14     PSTV15  PSTV16       PSTV17  PSTV18
# 94961     LOMBOK BARAT   3.706050    2019        AKTIF     NaN
# 94962         SUKABUMI  35.093258    2019  TIDAK AKTIF     NaN
# 94963     EMPAT LAWANG   2.652437    2019        AKTIF     NaN
# 94964  TAPANULI TENGAH  14.152590    2019    MENINGGAL  2019.0
# 94965         PEMALANG   1.224500    2019        AKTIF     NaN

# %%
data_kepersertaan2019.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
data_kepersertaan2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PSTV01  94966 non-null  int32
#  1   PSTV02  94966 non-null  int32
#  2   PSTV03  94966 non-null  datetime64[ns]
#  3   PSTV04  94966 non-null  category
#  4   PSTV05  94966 non-null  category
#  5   PSTV06  94966 non-null  category
#  6   PSTV07  94966 non-null  category
#  7   PSTV08  94966 non-null  category
#  8   PSTV09  94966 non-null  category
#  9   PSTV10  94966 non-null  category
#  10  PSTV11  94966 non-null  category
#  11  PSTV12  94966 non-null  category
#  12  PSTV13  94966 non-null  category
#  13  PSTV14  94966 non-null  category
#  14  PSTV15  94966 non-null  float32
#  15  PSTV16  94966 non-null  int16
#  16  PSTV17  94966 non-null  category
#  17  PSTV18  4476 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 4.8 MB

# %%
data_kepersertaan2019.dtypes
# Out:
# PSTV01             int32
# PSTV02             int32
# PSTV03    datetime64[ns]
# PSTV04          category
# PSTV05          category
# PSTV06          category
# PSTV07          category
# PSTV08          category
# PSTV09          category
# PSTV10          category
# PSTV11          category
# PSTV12          category
# PSTV13          category
# PSTV14          category
# PSTV15           float32
# PSTV16             int16
# PSTV17          category
# PSTV18           float64
# dtype: object

# %%
data_kepersertaan2019.describe()
# Out:
#              PSTV01        PSTV02        PSTV15   PSTV16  PSTV18
# count  9.496600e+04  9.496600e+04  94966.000000  94966.0  4476.0
# mean   1.830281e+08  1.903269e+08      8.461007   2019.0  2019.0
# std    1.597607e+08  1.607588e+08     19.109184      0.0     0.0
# min    1.394000e+03  3.687000e+03      0.156804   2019.0  2019.0
# 25%    4.366800e+07  4.563971e+07      1.154869   2019.0  2019.0
# 50%    8.745586e+07  9.109761e+07      2.845975   2019.0  2019.0
# 75%    3.455679e+08  3.518411e+08      7.727345   2019.0  2019.0
# max    4.553809e+08  4.553826e+08    365.923492   2019.0  2019.0

# %%
data_kepersertaan2019.isnull().sum()
# Out:
# PSTV01        0
# PSTV02        0
# PSTV03        0
# PSTV04        0
# PSTV05        0
# PSTV06        0
# PSTV07        0
# PSTV08        0
# PSTV09        0
# PSTV10        0
# PSTV11        0
# PSTV12        0
# PSTV13        0
# PSTV14        0
# PSTV15        0
# PSTV16        0
# PSTV17        0
# PSTV18    90490
# dtype: int64

# %%
duplicate_kepersertaan2019 = data_kepersertaan2019.duplicated()
duplicate_kepersertaan2019.sum()
# Out:
# 0

# %% [markdown]
# ### kepersertaan_2020

# %%
data_kepersertaan2020 = pd.read_stata('/content/drive/MyDrive/DAMI/TB2020_kepesertaan.dta')
data_kepersertaan2020.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06    PSTV07  \
# 0   32853965   31945523 1958-11-27    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 1    8555967    8555967 1936-07-01  PESERTA  LAKI-LAKI        KAWIN   KELAS I
# 2    8797049     249479 1950-07-21    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 3   83472658   54408870 2012-08-12     ANAK  PEREMPUAN  BELUM KAWIN   KELAS I
# 4  425874326  296852327 2004-12-30     ANAK  LAKI-LAKI  BELUM KAWIN  KELAS II
#
#           PSTV08          PSTV09        PSTV10                     PSTV11  \
# 0            PPU            ACEH   ACEH TENGAH  PEMERINTAH KABUPATEN/KOTA
# 1  BUKAN PEKERJA            ACEH   ACEH TENGAH                      POLRI
# 2  BUKAN PEKERJA            ACEH  ACEH SELATAN  PEMERINTAH KABUPATEN/KOTA
# 3            PPU            ACEH    ACEH BARAT  PEMERINTAH KABUPATEN/KOTA
# 4            PPU  SUMATERA UTARA  TOBA SAMOSIR  PEMERINTAH KABUPATEN/KOTA
#
#            PSTV12          PSTV13        PSTV14     PSTV15  PSTV16  \
# 0       PUSKESMAS            ACEH   ACEH TENGAH   1.531137    2020
# 1  KLINIK PRATAMA            ACEH       BIREUEN   0.998777    2020
# 2       PUSKESMAS            ACEH  ACEH SELATAN  30.096481    2020
# 3       PUSKESMAS            ACEH    ACEH BARAT   9.837102    2020
# 4       PUSKESMAS  SUMATERA UTARA  TOBA SAMOSIR   1.038886    2020
#
#         PSTV17  PSTV18
# 0    MENINGGAL  2020.0
# 1        AKTIF     NaN
# 2  TIDAK AKTIF     NaN
# 3        AKTIF     NaN
# 4        AKTIF     NaN

# %%
data_kepersertaan2020.shape
# Out:
# (94966, 18)

# %%
data_kepersertaan2020.tail()
# Out:
#           PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06  \
# 94961  441113640  353368323 1968-06-24    ISTRI  PEREMPUAN        KAWIN
# 94962  348921684  348921684 1954-03-10  PESERTA  PEREMPUAN        CERAI
# 94963  344293181  392640898 1975-07-07    ISTRI  PEREMPUAN        KAWIN
# 94964  411717961  411717961 2010-03-13  PESERTA  LAKI-LAKI  BELUM KAWIN
# 94965  278051593  278051593 1977-05-05  PESERTA  LAKI-LAKI        KAWIN
#
#           PSTV07    PSTV08            PSTV09             PSTV10  \
# 94961   KELAS II      PBPU          BENGKULU      KOTA BENGKULU
# 94962  KELAS III  PBI APBD  SUMATERA SELATAN       EMPAT LAWANG
# 94963  KELAS III  PBI APBD              RIAU          BENGKALIS
# 94964  KELAS III  PBI APBD       PAPUA BARAT  MANOKWARI SELATAN
# 94965  KELAS III      PBPU    SUMATERA UTARA    SERDANG BEDAGAI
#
#                           PSTV11     PSTV12            PSTV13  \
# 94961  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS          BENGKULU
# 94962  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS  SUMATERA SELATAN
# 94963  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS              RIAU
# 94964  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS       PAPUA BARAT
# 94965  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS    SUMATERA UTARA
#
#                   PSTV14     PSTV15  PSTV16       PSTV17  PSTV18
# 94961      KOTA BENGKULU  11.074059    2020    MENINGGAL  2019.0
# 94962       EMPAT LAWANG   1.168197    2020        AKTIF     NaN
# 94963          BENGKALIS   1.783689    2020        AKTIF     NaN
# 94964  MANOKWARI SELATAN   1.025151    2020        AKTIF     NaN
# 94965    SERDANG BEDAGAI  14.769157    2020  TIDAK AKTIF     NaN

# %%
data_kepersertaan2020.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
data_kepersertaan2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PSTV01  94966 non-null  int32
#  1   PSTV02  94966 non-null  int32
#  2   PSTV03  94966 non-null  datetime64[ns]
#  3   PSTV04  94966 non-null  category
#  4   PSTV05  94966 non-null  category
#  5   PSTV06  94966 non-null  category
#  6   PSTV07  94966 non-null  category
#  7   PSTV08  94966 non-null  category
#  8   PSTV09  94966 non-null  category
#  9   PSTV10  94966 non-null  category
#  10  PSTV11  94966 non-null  category
#  11  PSTV12  94966 non-null  category
#  12  PSTV13  94966 non-null  category
#  13  PSTV14  94966 non-null  category
#  14  PSTV15  94966 non-null  float32
#  15  PSTV16  94966 non-null  int16
#  16  PSTV17  94966 non-null  category
#  17  PSTV18  7147 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 4.8 MB

# %%
data_kepersertaan2020.dtypes
# Out:
# PSTV01             int32
# PSTV02             int32
# PSTV03    datetime64[ns]
# PSTV04          category
# PSTV05          category
# PSTV06          category
# PSTV07          category
# PSTV08          category
# PSTV09          category
# PSTV10          category
# PSTV11          category
# PSTV12          category
# PSTV13          category
# PSTV14          category
# PSTV15           float32
# PSTV16             int16
# PSTV17          category
# PSTV18           float64
# dtype: object

# %%
data_kepersertaan2020.describe()
# Out:
#              PSTV01        PSTV02        PSTV15   PSTV16       PSTV18
# count  9.496600e+04  9.496600e+04  94966.000000  94966.0  7147.000000
# mean   1.830281e+08  1.903269e+08      8.461007   2020.0  2019.370365
# std    1.597607e+08  1.607588e+08     19.109184      0.0     0.482936
# min    1.394000e+03  3.687000e+03      0.156804   2020.0  2019.000000
# 25%    4.366800e+07  4.563971e+07      1.154869   2020.0  2019.000000
# 50%    8.745586e+07  9.109761e+07      2.845975   2020.0  2019.000000
# 75%    3.455679e+08  3.518411e+08      7.727345   2020.0  2020.000000
# max    4.553809e+08  4.553826e+08    365.923492   2020.0  2020.000000

# %%
data_kepersertaan2020.isnull().sum()
# Out:
# PSTV01        0
# PSTV02        0
# PSTV03        0
# PSTV04        0
# PSTV05        0
# PSTV06        0
# PSTV07        0
# PSTV08        0
# PSTV09        0
# PSTV10        0
# PSTV11        0
# PSTV12        0
# PSTV13        0
# PSTV14        0
# PSTV15        0
# PSTV16        0
# PSTV17        0
# PSTV18    87819
# dtype: int64

# %%
duplicate_kepersertaan2020 = data_kepersertaan2020.duplicated()
duplicate_kepersertaan2020.sum()
# Out:
# 0

# %% [markdown]
# ### kepersertaan_2021

# %%
data_kepersertaan2021 = pd.read_stata('/content/drive/MyDrive/DAMI/TB2021_kepesertaan.dta')
data_kepersertaan2021.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06    PSTV07  \
# 0   32853965   31945523 1958-11-27    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 1    8555967    8555967 1936-07-01  PESERTA  LAKI-LAKI        KAWIN   KELAS I
# 2    8797049     249479 1950-07-21    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 3   83472658   54408870 2012-08-12     ANAK  PEREMPUAN  BELUM KAWIN   KELAS I
# 4  425874326  296852327 2004-12-30     ANAK  LAKI-LAKI  BELUM KAWIN  KELAS II
#
#           PSTV08          PSTV09        PSTV10                     PSTV11  \
# 0            PPU            ACEH   ACEH TENGAH  PEMERINTAH KABUPATEN/KOTA
# 1  BUKAN PEKERJA            ACEH   ACEH TENGAH                      POLRI
# 2  BUKAN PEKERJA            ACEH  ACEH SELATAN  PEMERINTAH KABUPATEN/KOTA
# 3            PPU            ACEH    ACEH BARAT  PEMERINTAH KABUPATEN/KOTA
# 4            PPU  SUMATERA UTARA  TOBA SAMOSIR  PEMERINTAH KABUPATEN/KOTA
#
#            PSTV12          PSTV13        PSTV14     PSTV15  PSTV16  \
# 0       PUSKESMAS            ACEH   ACEH TENGAH   1.531137    2021
# 1  KLINIK PRATAMA            ACEH       BIREUEN   0.998777    2021
# 2       PUSKESMAS            ACEH  ACEH SELATAN  30.096481    2021
# 3       PUSKESMAS            ACEH    ACEH BARAT   9.837102    2021
# 4       PUSKESMAS  SUMATERA UTARA  TOBA SAMOSIR   1.038886    2021
#
#         PSTV17  PSTV18
# 0    MENINGGAL  2020.0
# 1        AKTIF     NaN
# 2  TIDAK AKTIF     NaN
# 3        AKTIF     NaN
# 4        AKTIF     NaN

# %%
data_kepersertaan2021.shape
# Out:
# (94966, 18)

# %%
data_kepersertaan2021.tail()
# Out:
#           PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06  \
# 94961  441113640  353368323 1968-06-24    ISTRI  PEREMPUAN        KAWIN
# 94962  348921684  348921684 1954-03-10  PESERTA  PEREMPUAN        CERAI
# 94963  344293181  392640898 1975-07-07    ISTRI  PEREMPUAN        KAWIN
# 94964  411717961  411717961 2010-03-13  PESERTA  LAKI-LAKI  BELUM KAWIN
# 94965  278051593  278051593 1977-05-05  PESERTA  LAKI-LAKI        KAWIN
#
#           PSTV07    PSTV08            PSTV09             PSTV10  \
# 94961   KELAS II      PBPU          BENGKULU      KOTA BENGKULU
# 94962  KELAS III  PBI APBD  SUMATERA SELATAN       EMPAT LAWANG
# 94963  KELAS III  PBI APBD              RIAU          BENGKALIS
# 94964  KELAS III  PBI APBD       PAPUA BARAT  MANOKWARI SELATAN
# 94965  KELAS III      PBPU    SUMATERA UTARA    SERDANG BEDAGAI
#
#                           PSTV11     PSTV12            PSTV13  \
# 94961  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS          BENGKULU
# 94962  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS  SUMATERA SELATAN
# 94963  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS              RIAU
# 94964  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS       PAPUA BARAT
# 94965  PEMERINTAH KABUPATEN/KOTA  PUSKESMAS    SUMATERA UTARA
#
#                   PSTV14     PSTV15  PSTV16       PSTV17  PSTV18
# 94961      KOTA BENGKULU  11.074059    2021    MENINGGAL  2019.0
# 94962       EMPAT LAWANG   1.168197    2021        AKTIF     NaN
# 94963          BENGKALIS   1.783689    2021        AKTIF     NaN
# 94964  MANOKWARI SELATAN   1.025151    2021        AKTIF     NaN
# 94965    SERDANG BEDAGAI  14.769157    2021  TIDAK AKTIF     NaN

# %%
data_kepersertaan2021.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
data_kepersertaan2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PSTV01  94966 non-null  int32
#  1   PSTV02  94966 non-null  int32
#  2   PSTV03  94966 non-null  datetime64[ns]
#  3   PSTV04  94966 non-null  category
#  4   PSTV05  94966 non-null  category
#  5   PSTV06  94966 non-null  category
#  6   PSTV07  94966 non-null  category
#  7   PSTV08  94966 non-null  category
#  8   PSTV09  94966 non-null  category
#  9   PSTV10  94966 non-null  category
#  10  PSTV11  94966 non-null  category
#  11  PSTV12  94966 non-null  category
#  12  PSTV13  94966 non-null  category
#  13  PSTV14  94966 non-null  category
#  14  PSTV15  94966 non-null  float32
#  15  PSTV16  94966 non-null  int16
#  16  PSTV17  94966 non-null  category
#  17  PSTV18  8654 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 4.8 MB

# %%
data_kepersertaan2021.dtypes
# Out:
# PSTV01             int32
# PSTV02             int32
# PSTV03    datetime64[ns]
# PSTV04          category
# PSTV05          category
# PSTV06          category
# PSTV07          category
# PSTV08          category
# PSTV09          category
# PSTV10          category
# PSTV11          category
# PSTV12          category
# PSTV13          category
# PSTV14          category
# PSTV15           float32
# PSTV16             int16
# PSTV17          category
# PSTV18           float64
# dtype: object

# %%
data_kepersertaan2021.describe()
# Out:
#              PSTV01        PSTV02        PSTV15   PSTV16       PSTV18
# count  9.496600e+04  9.496600e+04  94966.000000  94966.0  8654.000000
# mean   1.830281e+08  1.903269e+08      8.461007   2021.0  2019.656344
# std    1.597607e+08  1.607588e+08     19.109184      0.0     0.759391
# min    1.394000e+03  3.687000e+03      0.156804   2021.0  2019.000000
# 25%    4.366800e+07  4.563971e+07      1.154869   2021.0  2019.000000
# 50%    8.745586e+07  9.109761e+07      2.845975   2021.0  2019.000000
# 75%    3.455679e+08  3.518411e+08      7.727345   2021.0  2020.000000
# max    4.553809e+08  4.553826e+08    365.923492   2021.0  2021.000000

# %%
data_kepersertaan2021.isnull().sum()
# Out:
# PSTV01        0
# PSTV02        0
# PSTV03        0
# PSTV04        0
# PSTV05        0
# PSTV06        0
# PSTV07        0
# PSTV08        0
# PSTV09        0
# PSTV10        0
# PSTV11        0
# PSTV12        0
# PSTV13        0
# PSTV14        0
# PSTV15        0
# PSTV16        0
# PSTV17        0
# PSTV18    86312
# dtype: int64

# %%
duplicate_kepersertaan2021 = data_kepersertaan2021.duplicated()
duplicate_kepersertaan2021.sum()
# Out:
# 0
